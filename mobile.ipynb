# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv("../input/mobile-phone-rating/mobile phone rating by dxo.csv")
dataset.head()

# %%
dataset.info()

# %%
dataset.isnull().sum()

# %%
dataset.mean()

# %%
dt1=dataset.replace(np.NAN,dataset.mean()).head(15)
dt1

# %%
dt1.isnull().sum()

# %%
dt1['price'] = dt1['price'].apply(lambda x: str(x).replace('$', '') if '$' in str(x) else str(x))
dt1['price'] = dt1['price'].apply(lambda x: float(x))
dt1.info()
